# %%
import json
import os

# %%
file_path = os.path.abspath("data/route.json")
data = None
with open(file_path, 'r') as f:
  data = json.load(f)
  
print(json.dumps(data, indent=False))
# Out:
# {
# "openapi": "3.0.3",
# "info": {
# "title": "My API",
# "description": "REST API documentation generated from JSON examples",
# "version": "3.0.3"
# },
# "servers": [
# {
# "url": "https://api.freeapi.app/api/v1/",
# "description": "Production server"
# }
# ],
# "paths": {
# "/public/randomusers?page=1&limit=10": {
# "get": {
# "summary": "GET /public/randomusers?page=1&limit=10",
# "description": "GET operation for /public/randomusers?page=1&limit=10",
# "parameters": [],
# "responses": {
# "200": {
# "description": "Successful response",
# "content": {
# "application/json": {
# "schema": {
# "$ref": "#/components/schemas/MyAPI"
# }
# }
# }
# },
# "400": {
# "description": "Bad request"
# },
# "404": {
# "description": "Not found"
# },
# "500": {
# "description": "Internal server error"
# }
# }
# }
# }
# },
# "components": {
# "schemas": {
# "MyAPI": {
# "type": "object",
# "properties": {
# "data": {
# "type": "object",
# "properties": {
# "currentPageItems": {
# ...
